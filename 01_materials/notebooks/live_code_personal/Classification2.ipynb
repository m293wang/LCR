# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import recall_score, precision_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV

# %%
cancer = pd.read_csv(r'C:\Users\m293w\Documents\Data Science\DSI Cert\LCR\01_materials\notebooks\dataset\wdbc.csv')
cancer
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0    ...        25.380          17.33           184.60      2019.0
# 1    ...        24.990          23.41           158.80      1956.0
# 2    ...        23.570          25.53           152.50      1709.0
# 3    ...        14.910          26.50            98.87       567.7
# 4    ...        22.540          16.67           152.20      1575.0
# ..   ...           ...            ...              ...         ...
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
cancer['diagnosis'] = cancer['diagnosis'].replace({
    'M': 'Malignant',
    'B': 'Benign'
})

cancer['diagnosis'].unique()
# Out:
# array(['Malignant', 'Benign'], dtype=object)

# %%
# Scaling

standardized_cancer = cancer.copy()

columns_to_exclude = ['id', 'diagnosis']
columns_to_scale = standardized_cancer.columns.difference(columns_to_exclude)

scaler = StandardScaler()
standardized_cancer[columns_to_scale] = scaler.fit_transform(standardized_cancer[columns_to_scale])

standardized_cancer
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302  Malignant     1.097064     -2.073335        1.269934
# 1      842517  Malignant     1.829821     -0.353632        1.685955
# 2    84300903  Malignant     1.579888      0.456187        1.566503
# 3    84348301  Malignant    -0.768909      0.253732       -0.592687
# 4    84358402  Malignant     1.750297     -1.151816        1.776573
# ..        ...        ...          ...           ...             ...
# 564    926424  Malignant     2.110995      0.721473        2.060786
# 565    926682  Malignant     1.704854      2.085134        1.615931
# 566    926954  Malignant     0.702284      2.045574        0.672676
# 567    927241  Malignant     1.838341      2.336457        1.982524
# 568     92751     Benign    -1.808401      1.221792       -1.814389
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     0.984375         1.568466          3.283515        2.652874
# 1     1.908708        -0.826962         -0.487072       -0.023846
# 2     1.558884         0.942210          1.052926        1.363478
# 3    -0.764464         3.283553          3.402909        1.915897
# 4     1.826229         0.280372          0.539340        1.371011
# ..         ...              ...               ...             ...
# 564   2.343856         1.041842          0.219060        1.947285
# 565   1.723842         0.102458         -0.017833        0.693043
# 566   0.577953        -0.840484         -0.038680        0.046588
# 567   1.735218         1.525767          3.272144        3.296944
# 568  -1.347789        -3.112085         -1.150752       -1.114873
#
#      concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0               2.532475  ...      1.886690      -1.359293         2.303601
# 1               0.548144  ...      1.805927      -0.369203         1.535126
# 2               2.037231  ...      1.511870      -0.023974         1.347475
# 3               1.451707  ...     -0.281464       0.133984        -0.249939
# 4               1.428493  ...      1.298575      -1.466770         1.338539
# ..                   ...  ...           ...            ...              ...
# 564             2.320965  ...      1.901185       0.117700         1.752563
# 565             1.263669  ...      1.536720       2.047399         1.421940
# 566             0.105777  ...      0.561361       1.374854         0.579001
# 567             2.658866  ...      1.961239       2.237926         2.303601
# 568            -1.261820  ...     -1.410893       0.764190        -1.432735
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2.001237          1.307686           2.616665         2.109526
# 1      1.890489         -0.375612          -0.430444        -0.146749
# 2      1.456285          0.527407           1.082932         0.854974
# 3     -0.550021          3.394275           3.893397         1.989588
# 4      1.220724          0.220556          -0.313395         0.613179
# ..          ...               ...                ...              ...
# 564    2.015301          0.378365          -0.273318         0.664512
# 565    1.494959         -0.691230          -0.394820         0.236573
# 566    0.427906         -0.809587           0.350735         0.326767
# 567    1.653171          1.430427           3.904848         3.197605
# 568   -1.075813         -1.859019          -1.207552        -1.305831
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                2.296076        2.750622                 1.937015
# 1                1.087084       -0.243890                 0.281190
# 2                1.955000        1.152255                 0.201391
# 3                2.175786        6.046041                 4.935010
# 4                0.729259       -0.868353                -0.397100
# ..                    ...             ...                      ...
# 564              1.629151       -1.360158                -0.709091
# 565              0.733827       -0.531855                -0.973978
# 566              0.414069       -1.104549                -0.318409
# 567              2.289985        1.919083                 2.219635
# 568             -1.745063       -0.048138                -0.751207
#
# [569 rows x 32 columns]

# %%
np.random.seed(1)
cancer_train, cancer_test = train_test_split(
    standardized_cancer, train_size = 0.75, shuffle = True, #Don't let the order of data input affect the split
    stratify = standardized_cancer['diagnosis'] #Making sure we have relatively equivalent # of parameters
)

# %%
#cancer_train.info()
cancer_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 143 entries, 357 to 332
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       143 non-null    int64
#  1   diagnosis                143 non-null    object
#  2   radius_mean              143 non-null    float64
#  3   texture_mean             143 non-null    float64
#  4   perimeter_mean           143 non-null    float64
#  5   area_mean                143 non-null    float64
#  6   smoothness_mean          143 non-null    float64
#  7   compactness_mean         143 non-null    float64
#  8   concavity_mean           143 non-null    float64
#  9   concave points_mean      143 non-null    float64
#  10  symmetry_mean            143 non-null    float64
#  11  fractal_dimension_mean   143 non-null    float64
#  12  radius_se                143 non-null    float64
#  13  texture_se               143 non-null    float64
#  14  perimeter_se             143 non-null    float64
#  15  area_se                  143 non-null    float64
#  16  smoothness_se            143 non-null    float64
#  17  compactness_se           143 non-null    float64
#  18  concavity_se             143 non-null    float64
#  19  concave points_se        143 non-null    float64
#  20  symmetry_se              143 non-null    float64
#  21  fractal_dimension_se     143 non-null    float64
#  22  radius_worst             143 non-null    float64
#  23  texture_worst            143 non-null    float64
#  24  perimeter_worst          143 non-null    float64
#  25  area_worst               143 non-null    float64
#  26  smoothness_worst         143 non-null    float64
#  27  compactness_worst        143 non-null    float64
#  28  concavity_worst          143 non-null    float64
#  29  concave points_worst     143 non-null    float64
#  30  symmetry_worst           143 non-null    float64
#  31  fractal_dimension_worst  143 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 36.9+ KB

# %%
knn = KNeighborsClassifier(n_neighbors=5)
X = cancer_train[['perimeter_mean', 'concavity_mean']]
y = cancer_train['diagnosis']

knn.fit(X, y)
# Out:
# KNeighborsClassifier()

# %%
cancer_test['predicted'] = knn.predict(cancer_test[['perimeter_mean', 'concavity_mean']])

cancer_test['predicted']
# Out:
# 357       Benign
# 361       Benign
# 212    Malignant
# 527       Benign
# 21        Benign
#          ...
# 364       Benign
# 434       Benign
# 299       Benign
# 488       Benign
# 332       Benign
# Name: predicted, Length: 143, dtype: object

# %%
knn.score(cancer_test[['perimeter_mean', 'concavity_mean']], cancer_test['diagnosis'])
# Out:
# 0.9230769230769231

# %%
#creating confusion matrix
pd.crosstab(
    cancer_test['diagnosis'],
    cancer_test['predicted'],
    rownames = ['Actual'],
    colnames = ['Predicted']
)
# Out:
# Predicted  Benign  Malignant
# Actual
# Benign         88          2
# Malignant       9         44

# %%
precision_score(
    y_true = cancer_test['diagnosis'],
    y_pred = cancer_test['predicted'],
    pos_label = 'Malignant'
)
# Out:
# 0.9565217391304348

# %%
recall_score(
    y_true = cancer_test['diagnosis'],
    y_pred = cancer_test['predicted'],
    pos_label = 'Malignant'
)
# Out:
# 0.8301886792452831

# %%
#split training function again to get validation set within it

cancer_subtrain, cancer_validation = train_test_split(
    cancer_train, train_size = 0.75,
    stratify = cancer_train['diagnosis']
)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
X = cancer_subtrain[['perimeter_mean', 'concavity_mean']]
y = cancer_subtrain['diagnosis']
knn.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
acc = knn.score(
    cancer_validation[['perimeter_mean', 'concavity_mean']],
    cancer_validation['diagnosis']
)

acc
# Out:
# 0.8785046728971962

# %%
knn = KNeighborsClassifier(n_neighbors=3)
X = cancer_train[['perimeter_mean', 'concavity_mean']]
y = cancer_train['diagnosis']

returned_dictionary = cross_validate(
    estimator = knn,
    cv = 5, #divisions
    X = X,
    y = y
)

cv_5_df = pd.DataFrame(returned_dictionary)
cv_5_df
# Out:
#    fit_time  score_time  test_score
# 0  0.004550    0.009811    0.930233
# 1  0.004204    0.012096    0.894118
# 2  0.004510    0.007732    0.870588
# 3  0.003107    0.006795    0.952941
# 4  0.002245    0.006792    0.917647

# %%
cv_5_metrics = cv_5_df.agg(['mean', 'sem'])
cv_5_metrics
# Out:
#       fit_time  score_time  test_score
# mean  0.003610    0.009263    0.913105
# sem   0.000615    0.000948    0.014264

# %%
parameter_grid = {
    'n_neighbors': range(1, 350, 10)
}
parameter_grid
# Out:
# {'n_neighbors': range(1, 350, 10)}

# %%
cancer_tune_grid = GridSearchCV(
    estimator = knn,
    param_grid = parameter_grid,
    cv = 10
)

# %%
cancer_tune_grid.fit(
    cancer_train[['perimeter_mean', 'concavity_mean']],
    cancer_train['diagnosis']
)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(n_neighbors=3),
#              param_grid={'n_neighbors': range(1, 350, 10)})

# %%
accuracy_grid = pd.DataFrame(cancer_tune_grid.cv_results_)
accuracy_grid
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002860      0.000807         0.005926        0.001090
# 1        0.002595      0.000468         0.005064        0.000781
# 2        0.003476      0.001565         0.007893        0.002567
# 3        0.003240      0.000814         0.006675        0.001405
# 4        0.002768      0.000521         0.005695        0.001037
# 5        0.002352      0.000672         0.006050        0.001233
# 6        0.002516      0.000599         0.005612        0.000503
# 7        0.002969      0.001122         0.006791        0.001117
# 8        0.002408      0.000706         0.006242        0.000799
# 9        0.002731      0.000921         0.005979        0.000954
# 10       0.002414      0.000613         0.005841        0.001068
# 11       0.002853      0.000958         0.006067        0.000856
# 12       0.002746      0.000598         0.005777        0.000610
# 13       0.002438      0.000613         0.005822        0.000741
# 14       0.002450      0.000502         0.005463        0.000726
# 15       0.002489      0.000631         0.005579        0.000687
# 16       0.002617      0.000594         0.005727        0.000770
# 17       0.002320      0.000645         0.005737        0.000883
# 18       0.002111      0.000359         0.006100        0.000767
# 19       0.002255      0.000553         0.032684        0.076891
# 20       0.002401      0.000854         0.008047        0.001008
# 21       0.002076      0.000540         0.007834        0.000717
# 22       0.001835      0.000400         0.008016        0.000863
# 23       0.002354      0.000723         0.008279        0.000918
# 24       0.002117      0.000614         0.008838        0.000869
# 25       0.002001      0.000119         0.007742        0.000749
# 26       0.002151      0.000521         0.008446        0.000868
# 27       0.002053      0.000522         0.007785        0.000804
# 28       0.002052      0.000732         0.008504        0.000802
# 29       0.002126      0.000566         0.008190        0.001028
# 30       0.002137      0.000575         0.008509        0.000957
# 31       0.002119      0.000460         0.008209        0.000795
# 32       0.002138      0.000343         0.008648        0.000751
# 33       0.001966      0.000616         0.008575        0.001252
# 34       0.002066      0.000614         0.008723        0.000905
#
#     param_n_neighbors                params  split0_test_score  \
# 0                   1    {'n_neighbors': 1}           0.953488
# 1                  11   {'n_neighbors': 11}           0.906977
# 2                  21   {'n_neighbors': 21}           0.906977
# 3                  31   {'n_neighbors': 31}           0.906977
# 4                  41   {'n_neighbors': 41}           0.906977
# 5                  51   {'n_neighbors': 51}           0.906977
# 6                  61   {'n_neighbors': 61}           0.906977
# 7                  71   {'n_neighbors': 71}           0.930233
# 8                  81   {'n_neighbors': 81}           0.930233
# 9                  91   {'n_neighbors': 91}           0.906977
# 10                101  {'n_neighbors': 101}           0.906977
# 11                111  {'n_neighbors': 111}           0.906977
# 12                121  {'n_neighbors': 121}           0.906977
# 13                131  {'n_neighbors': 131}           0.906977
# 14                141  {'n_neighbors': 141}           0.906977
# 15                151  {'n_neighbors': 151}           0.883721
# 16                161  {'n_neighbors': 161}           0.883721
# 17                171  {'n_neighbors': 171}           0.883721
# 18                181  {'n_neighbors': 181}           0.860465
# 19                191  {'n_neighbors': 191}           0.860465
# 20                201  {'n_neighbors': 201}           0.860465
# 21                211  {'n_neighbors': 211}           0.860465
# 22                221  {'n_neighbors': 221}           0.860465
# 23                231  {'n_neighbors': 231}           0.860465
# 24                241  {'n_neighbors': 241}           0.860465
# 25                251  {'n_neighbors': 251}           0.813953
# 26                261  {'n_neighbors': 261}           0.790698
# 27                271  {'n_neighbors': 271}           0.744186
# 28                281  {'n_neighbors': 281}           0.697674
# 29                291  {'n_neighbors': 291}           0.627907
# 30                301  {'n_neighbors': 301}           0.627907
# 31                311  {'n_neighbors': 311}           0.627907
# 32                321  {'n_neighbors': 321}           0.627907
# 33                331  {'n_neighbors': 331}           0.627907
# 34                341  {'n_neighbors': 341}           0.627907
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.837209           0.906977           0.860465
# 1            0.930233           0.906977           0.837209
# 2            0.953488           0.930233           0.837209
# 3            0.953488           0.930233           0.837209
# 4            0.953488           0.930233           0.837209
# 5            0.953488           0.930233           0.837209
# 6            0.953488           0.930233           0.860465
# 7            0.953488           0.930233           0.860465
# 8            0.976744           0.930233           0.860465
# 9            0.976744           0.930233           0.860465
# 10           0.976744           0.930233           0.860465
# 11           0.953488           0.930233           0.860465
# 12           0.953488           0.930233           0.860465
# 13           0.953488           0.930233           0.860465
# 14           0.953488           0.930233           0.883721
# 15           0.953488           0.930233           0.906977
# 16           0.953488           0.930233           0.906977
# 17           0.953488           0.906977           0.906977
# 18           0.930233           0.906977           0.883721
# 19           0.930233           0.906977           0.883721
# 20           0.930233           0.906977           0.883721
# 21           0.930233           0.906977           0.883721
# 22           0.883721           0.906977           0.883721
# 23           0.860465           0.930233           0.883721
# 24           0.860465           0.906977           0.883721
# 25           0.837209           0.906977           0.813953
# 26           0.790698           0.906977           0.790698
# 27           0.767442           0.860465           0.720930
# 28           0.674419           0.697674           0.697674
# 29           0.627907           0.627907           0.627907
# 30           0.627907           0.627907           0.627907
# 31           0.627907           0.627907           0.627907
# 32           0.627907           0.627907           0.627907
# 33           0.627907           0.627907           0.627907
# 34           0.627907           0.627907           0.627907
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 0            0.813953           0.837209           0.880952
# 1            0.837209           0.883721           0.952381
# 2            0.837209           0.906977           0.952381
# 3            0.837209           0.906977           0.952381
# 4            0.837209           0.883721           0.952381
# 5            0.837209           0.883721           0.952381
# 6            0.837209           0.906977           0.952381
# 7            0.837209           0.906977           0.952381
# 8            0.813953           0.906977           0.952381
# 9            0.813953           0.906977           0.904762
# 10           0.813953           0.906977           0.904762
# 11           0.813953           0.906977           0.880952
# 12           0.813953           0.906977           0.880952
# 13           0.813953           0.906977           0.880952
# 14           0.813953           0.906977           0.833333
# 15           0.813953           0.906977           0.809524
# 16           0.790698           0.906977           0.809524
# 17           0.790698           0.906977           0.809524
# 18           0.790698           0.906977           0.785714
# 19           0.790698           0.906977           0.785714
# 20           0.813953           0.906977           0.785714
# 21           0.813953           0.930233           0.785714
# 22           0.837209           0.930233           0.761905
# 23           0.837209           0.930233           0.761905
# 24           0.837209           0.930233           0.761905
# 25           0.790698           0.906977           0.738095
# 26           0.790698           0.837209           0.738095
# 27           0.790698           0.790698           0.666667
# 28           0.767442           0.744186           0.619048
# 29           0.627907           0.627907           0.619048
# 30           0.627907           0.627907           0.619048
# 31           0.627907           0.627907           0.619048
# 32           0.627907           0.627907           0.619048
# 33           0.627907           0.627907           0.619048
# 34           0.627907           0.627907           0.619048
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 0            0.904762           0.880952           0.880952         0.875692
# 1            0.904762           0.928571           0.952381         0.904042
# 2            0.952381           0.880952           0.976190         0.913400
# 3            0.928571           0.904762           0.976190         0.913400
# 4            0.928571           0.904762           0.976190         0.911074
# 5            0.952381           0.904762           0.976190         0.913455
# 6            0.952381           0.904762           0.976190         0.918106
# 7            0.952381           0.904762           0.976190         0.920432
# 8            0.952381           0.904762           0.976190         0.920432
# 9            0.952381           0.904762           0.976190         0.913344
# 10           0.952381           0.904762           0.976190         0.913344
# 11           0.952381           0.904762           0.976190         0.908638
# 12           0.952381           0.904762           0.976190         0.908638
# 13           0.952381           0.904762           0.976190         0.908638
# 14           0.928571           0.904762           0.976190         0.903821
# 15           0.928571           0.904762           0.976190         0.901440
# 16           0.904762           0.904762           0.952381         0.894352
# 17           0.904762           0.904762           0.952381         0.892027
# 18           0.904762           0.880952           0.952381         0.880288
# 19           0.904762           0.880952           0.928571         0.877907
# 20           0.904762           0.857143           0.928571         0.877852
# 21           0.904762           0.857143           0.928571         0.880177
# 22           0.904762           0.857143           0.928571         0.875471
# 23           0.904762           0.857143           0.904762         0.873090
# 24           0.904762           0.857143           0.904762         0.870764
# 25           0.880952           0.857143           0.880952         0.842691
# 26           0.833333           0.833333           0.880952         0.819269
# 27           0.738095           0.809524           0.833333         0.772204
# 28           0.690476           0.738095           0.761905         0.708859
# 29           0.619048           0.619048           0.642857         0.626744
# 30           0.619048           0.619048           0.642857         0.626744
# 31           0.619048           0.619048           0.642857         0.626744
# 32           0.619048           0.619048           0.642857         0.626744
# 33           0.619048           0.619048           0.642857         0.626744
# 34           0.619048           0.619048           0.642857         0.626744
#
#     std_test_score  rank_test_score
# 0         0.038684               22
# 1         0.039147               13
# 2         0.046495                5
# 3         0.043989                5
# 4         0.044873                9
# 5         0.046345                4
# 6         0.041731                3
# 7         0.041694                1
# 8         0.048861                1
# 9         0.047625                7
# 10        0.047625                7
# 11        0.045856               10
# 12        0.045856               10
# 13        0.045856               10
# 14        0.047417               14
# 15        0.051333               15
# 16        0.051711               16
# 17        0.050555               17
# 18        0.052049               18
# 19        0.049161               20
# 20        0.045907               21
# 21        0.047871               19
# 22        0.047673               23
# 23        0.047825               24
# 24        0.045499               25
# 25        0.051699               26
# 26        0.046978               27
# 27        0.054168               28
# 28        0.042795               29
# 29        0.006674               30
# 30        0.006674               30
# 31        0.006674               30
# 32        0.006674               30
# 33        0.006674               30
# 34        0.006674               30

# %%
# Create the plot
plt.figure(figsize=(10, 6))

# Plot mean test scores with error bars
plt.plot(accuracy_grid['param_n_neighbors'], accuracy_grid['mean_test_score'], '-o', color='blue')

# Add labels and legend
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy estimate')
plt.title('K-Nearest Neighbors Performance')
plt.tight_layout()
plt.show()

# %%
cancer_tune_grid.best_params_
# Out:
# {'n_neighbors': 71}
